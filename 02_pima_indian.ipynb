# %% [markdown]
# <a href="https://colab.research.google.com/github/ljm9748/deepstudy/blob/master/02_pima_indian.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 기본 환경설정

# %%
# !pip install tensorflow==2.1.0
# Out:
# ...
#      |████████████████████████████████| 421.8MB 39kB/s
# ...
#      |████████████████████████████████| 3.9MB 46.0MB/s
# ...
#      |████████████████████████████████| 450kB 38.5MB/s
# ...
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# ...
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import tensorflow as tf

# %%
np.random.seed(3)
tf.random.set_seed(3)

# %% [markdown]
# # 데이터 불러오기

# %%
dataset=np.loadtxt("/content/gdrive/My Drive/Colab Notebooks/deepstudy/deeplearning/dataset/pima-indians-diabetes.csv", delimiter=',')

# %%
X=dataset[:, 0:8]
Y=dataset[:, 8]

# %% [markdown]
# # 모델 설정, 컴파일, 실행

# %%
model=Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X, Y, epochs=200, batch_size=10)
# Out:
# Train on 768 samples
# Epoch 1/200
# 768/768 [==============================] - 0s 566us/sample - loss: 10.9665 - accuracy: 0.6224
# Epoch 2/200
# 768/768 [==============================] - 0s 132us/sample - loss: 5.9693 - accuracy: 0.6107
# Epoch 3/200
# 768/768 [==============================] - 0s 147us/sample - loss: 3.3368 - accuracy: 0.5208
# Epoch 4/200
# 768/768 [==============================] - 0s 131us/sample - loss: 1.9847 - accuracy: 0.5169
# Epoch 5/200
# 768/768 [==============================] - 0s 138us/sample - loss: 1.1698 - accuracy: 0.5391
# Epoch 6/200
# 768/768 [==============================] - 0s 150us/sample - loss: 0.8547 - accuracy: 0.5482
# Epoch 7/200
# 768/768 [==============================] - 0s 136us/sample - loss: 0.7792 - accuracy: 0.5521
# Epoch 8/200
# 768/768 [==============================] - 0s 148us/sample - loss: 0.7455 - accuracy: 0.5638
# Epoch 9/200
# ...

# %%
print("\n Accuracy:%.4f"%(model.evaluate(X, Y)[1]))
# Out:
# 768/768 [==============================] - 0s 124us/sample - loss: 0.4393 - accuracy: 0.7878
#
#  Accuracy:0.7878
