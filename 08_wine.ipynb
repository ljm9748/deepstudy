# %% [markdown]
# <a href="https://colab.research.google.com/github/ljm9748/deepstudy/blob/master/08_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install tensorflow==2.1.0
# Out:
# ...
#      |████████████████████████████████| 421.8MB 35kB/s
# ...
#      |████████████████████████████████| 450kB 44.1MB/s
# ...
#      |████████████████████████████████| 3.9MB 42.0MB/s
# ...
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# ...
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping

import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)

# %%
df_pre = pd.read_csv(r'/content/gdrive/My Drive/Colab Notebooks/deepstudy/deeplearning/dataset/wine.csv')
df = df_pre.sample(frac=1)

dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# %%
model.fit(X, Y, epochs=200, batch_size=200)
# Out:
# Train on 6496 samples
# Epoch 1/200
# 6496/6496 [==============================] - 0s 68us/sample - loss: 0.6565 - accuracy: 0.7518
# Epoch 2/200
# 6496/6496 [==============================] - 0s 8us/sample - loss: 0.2991 - accuracy: 0.9053
# Epoch 3/200
# 6496/6496 [==============================] - 0s 8us/sample - loss: 0.2441 - accuracy: 0.9252
# Epoch 4/200
# 6496/6496 [==============================] - 0s 8us/sample - loss: 0.2292 - accuracy: 0.9247
# Epoch 5/200
# 6496/6496 [==============================] - 0s 9us/sample - loss: 0.2202 - accuracy: 0.9267
# Epoch 6/200
# 6496/6496 [==============================] - 0s 8us/sample - loss: 0.2132 - accuracy: 0.9300
# Epoch 7/200
# 6496/6496 [==============================] - 0s 8us/sample - loss: 0.2054 - accuracy: 0.9326
# Epoch 8/200
# 6496/6496 [==============================] - 0s 8us/sample - loss: 0.1974 - accuracy: 0.9349
# Epoch 9/200
# ...

# %%
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# 6496/6496 [==============================] - 0s 43us/sample - loss: 0.0546 - accuracy: 0.9831
#
#  Accuracy: 0.9831
