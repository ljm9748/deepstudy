# %% [markdown]
# <a href="https://colab.research.google.com/github/ljm9748/deepstudy/blob/master/11_Wine_Early_Stop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !pip install tensorflow==2.1.0
# Out:
# ...
#      |████████████████████████████████| 421.8MB 37kB/s
# ...
#      |████████████████████████████████| 3.9MB 12.3MB/s
# ...
#      |████████████████████████████████| 450kB 16.7MB/s
# ...
# ERROR: tensorflow-federated 0.12.0 has requirement tensorflow-addons~=0.7.0, but you'll have tensorflow-addons 0.8.3 which is incompatible.
# ...
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
#   Found existing installation: tensorflow 1.15.0
#     Uninstalling tensorflow-1.15.0:
#       Successfully uninstalled tensorflow-1.15.0
# ...

# %%
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras import Sequential
from tensorflow.python.keras.callbacks import EarlyStopping

import pandas as pd
import numpy
import tensorflow as tf
import matplotlib.pyplot as plt
import os

# %%
numpy.random.seed(3)
tf.random.set_seed(3)

# %%
df_pre = pd.read_csv(r"/content/gdrive/My Drive/Colab Notebooks/deepstudy/deeplearning/dataset/wine.csv", header=None)
df = df_pre.sample(frac=1)

# %%
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
           optimizer='adam',
           metrics=['accuracy'])

# %%
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

# %%
model.fit(X, Y, validation_split=0.2, epochs=2000, batch_size=500, callbacks=[early_stopping_callback])
# Out:
# Train on 5197 samples, validate on 1300 samples
# Epoch 1/2000
# 5197/5197 [==============================] - 0s 93us/sample - loss: 1.0378 - accuracy: 0.7158 - val_loss: 0.5859 - val_accuracy: 0.7054
# Epoch 2/2000
# 5197/5197 [==============================] - 0s 6us/sample - loss: 0.5156 - accuracy: 0.7516 - val_loss: 0.4450 - val_accuracy: 0.7669
# Epoch 3/2000
# 5197/5197 [==============================] - 0s 6us/sample - loss: 0.4006 - accuracy: 0.8107 - val_loss: 0.3512 - val_accuracy: 0.8608
# Epoch 4/2000
# 5197/5197 [==============================] - 0s 6us/sample - loss: 0.3358 - accuracy: 0.8745 - val_loss: 0.3077 - val_accuracy: 0.9069
# Epoch 5/2000
# 5197/5197 [==============================] - 0s 6us/sample - loss: 0.2972 - accuracy: 0.9053 - val_loss: 0.2803 - val_accuracy: 0.9238
# Epoch 6/2000
# 5197/5197 [==============================] - 0s 8us/sample - loss: 0.2730 - accuracy: 0.9148 - val_loss: 0.2602 - val_accuracy: 0.9269
# Epoch 7/2000
# ...

# %%
print("\n Accuracy: %.4f" % (model.evaluate(X, Y)[1]))
# Out:
# 6497/6497 [==============================] - 0s 34us/sample - loss: 0.0528 - accuracy: 0.9831
#
#  Accuracy: 0.9831
